# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
scores = {'Algos':['RFC', 'XGB','LGBM','CatB','VC'], 'Specificity':[], 'Sensitivity':[], 'Precision':[], 'F1':[]}

# %% [markdown]
# ####Combined Dataset

# %%
scores['Specificity'] = [97.82, 97.43, 97.59, 97.35, 97.53]
scores['Sensitivity'] = [84.40, 85.84, 87.04, 85.92, 86.35]
scores['Precision'] = [89.97, 88.50, 88.61, 88.18, 88.69]
scores['F1'] = [86.81, 86.91, 87.45, 86.80, 87.26]

# %%
results = pd.DataFrame(scores)
resm = results.melt('Algos', var_name='Metrics', value_name='values')
resm
# Out:
#    Algos      Metrics  values
# 0    RFC  Specificity   97.82
# 1    XGB  Specificity   97.43
# 2   LGBM  Specificity   97.59
# 3   CatB  Specificity   97.35
# 4     VC  Specificity   97.53
# 5    RFC  Sensitivity   84.40
# 6    XGB  Sensitivity   85.84
# 7   LGBM  Sensitivity   87.04
# 8   CatB  Sensitivity   85.92
# 9     VC  Sensitivity   86.35
# 10   RFC    Precision   89.97
# 11   XGB    Precision   88.50
# 12  LGBM    Precision   88.61
# 13  CatB    Precision   88.18
# 14    VC    Precision   88.69
# 15   RFC           F1   86.81
# 16   XGB           F1   86.91
# 17  LGBM           F1   87.45
# 18  CatB           F1   86.80
# 19    VC           F1   87.26

# %%
sns.catplot(x='Algos', y="values", hue="Metrics", data=resm, kind="point").set(title="Combined Data")
plt.legend(title='Metrics', fontsize=11)
plt.xlabel('Algos', fontsize=15);
plt.ylabel('values', fontsize=15);
plt.title('Combined Data', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)

# %% [markdown]
# ####Albert Dataset

# %%
scores['Specificity'] = [99.55, 99.42, 99.43, 99.46, 99.48]
scores['Sensitivity'] = [93.40, 94.13, 94.35, 91.43, 94.97]
scores['Precision'] = [96.19, 95.12, 95.20, 95.20, 95.56]
scores['F1'] = [94.51, 94.88, 94.72, 92.96, 95.06]

results = pd.DataFrame(scores)
resm = results.melt('Algos', var_name='Metrics', value_name='values')
resm
# Out:
#    Algos      Metrics  values
# 0    RFC  Specificity   99.55
# 1    XGB  Specificity   99.42
# 2   LGBM  Specificity   99.43
# 3   CatB  Specificity   99.46
# 4     VC  Specificity   99.48
# 5    RFC  Sensitivity   93.40
# 6    XGB  Sensitivity   94.13
# 7   LGBM  Sensitivity   94.35
# 8   CatB  Sensitivity   91.43
# 9     VC  Sensitivity   94.97
# 10   RFC    Precision   96.19
# 11   XGB    Precision   95.12
# 12  LGBM    Precision   95.20
# 13  CatB    Precision   95.20
# 14    VC    Precision   95.56
# 15   RFC           F1   94.51
# 16   XGB           F1   94.88
# 17  LGBM           F1   94.72
# 18  CatB           F1   92.96
# 19    VC           F1   95.06

# %%
sns.catplot(x='Algos', y="values", hue="Metrics", data=resm, kind="point").set(title="Albert Einstein Data")
plt.legend(title='Metrics', fontsize=9)
plt.xlabel('Algos', fontsize=15);
plt.ylabel('values', fontsize=15);
plt.title('Albert Einstein Data', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)

# %% [markdown]
# ####Covid Study Dataset

# %%
scores['Specificity'] = [91.62,96.58,10.00,96.58,93.49]
scores['Sensitivity'] = [97.75,96.66,90.00,97.28,97.79]
scores['Precision'] = [93.81,97.83,53.57,97.83,95.58]
scores['F1'] = [95.56,97.09,66.95,97.41,96.47]

results = pd.DataFrame(scores)
resm = results.melt('Algos', var_name='Metrics', value_name='values')
resm
# Out:
#    Algos      Metrics  values
# 0    RFC  Specificity   91.62
# 1    XGB  Specificity   96.58
# 2   LGBM  Specificity   10.00
# 3   CatB  Specificity   96.58
# 4     VC  Specificity   93.49
# 5    RFC  Sensitivity   97.75
# 6    XGB  Sensitivity   96.66
# 7   LGBM  Sensitivity   90.00
# 8   CatB  Sensitivity   97.28
# 9     VC  Sensitivity   97.79
# 10   RFC    Precision   93.81
# 11   XGB    Precision   97.83
# 12  LGBM    Precision   53.57
# 13  CatB    Precision   97.83
# 14    VC    Precision   95.58
# 15   RFC           F1   95.56
# 16   XGB           F1   97.09
# 17  LGBM           F1   66.95
# 18  CatB           F1   97.41
# 19    VC           F1   96.47

# %%
sns.catplot(x='Algos', y="values", hue="Metrics", data=resm, kind="point").set(title="Albert Einstein Data")
plt.legend(title='Metrics', fontsize=11)
plt.xlabel('Algos', fontsize=15);
plt.ylabel('values', fontsize=15);
plt.title('Covid Study Data', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)

# %% [markdown]
# ####All Training

# %%
scores['Specificity'] = [99.78, 99.21, 99.23,99.09,99.32]
scores['Sensitivity'] = [99.75, 99.75, 81.80,99.75,99.75]
scores['Precision'] = [99.76, 99.47, 81.48,99.41,99.53]
scores['F1'] = [99.76, 99.20, 81.18,99.09,99.31]

results = pd.DataFrame(scores)
resm = results.melt('Algos', var_name='Metrics', value_name='values')
resm
# Out:
#    Algos      Metrics  values
# 0    RFC  Specificity   99.78
# 1    XGB  Specificity   99.21
# 2   LGBM  Specificity   99.23
# 3   CatB  Specificity   99.09
# 4     VC  Specificity   99.32
# 5    RFC  Sensitivity   99.75
# 6    XGB  Sensitivity   99.75
# 7   LGBM  Sensitivity   81.80
# 8   CatB  Sensitivity   99.75
# 9     VC  Sensitivity   99.75
# 10   RFC    Precision   99.76
# 11   XGB    Precision   99.47
# 12  LGBM    Precision   81.48
# 13  CatB    Precision   99.41
# 14    VC    Precision   99.53
# 15   RFC           F1   99.76
# 16   XGB           F1   99.20
# 17  LGBM           F1   81.18
# 18  CatB           F1   99.09
# 19    VC           F1   99.31

# %%
sns.catplot(x='Algos', y="values", hue="Metrics", data=resm, kind="point").set(title="All training Data")
plt.legend(title='Metrics', fontsize=11)
plt.xlabel('Algos', fontsize=15);
plt.ylabel('values', fontsize=15);
plt.title('All training Data', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
